# %%
import pandas as pd
import pandas as pd
from sqlalchemy import create_engine
from tqdm import tqdm
import psycopg2
import click

# %%
url2 = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv'

# %%
dtype = {
"LocationID": "int64",
    "Borough": "string",
    "Zone": "string",
    "service_zone": "string"
    }

# %%
df = pd.read_csv(url2,dtype=dtype)
len(df)
# Out:
# 265

# %%
df.head(5)
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
try:
    conn = psycopg2.connect(
        host="127.0.0.1",
        port=5432,
        user="root",
        password="root",
        dbname="Trips_Ingestion"  # ✅ correct case
    )
    print("Connection successful!")
    conn.close()
except Exception as e:
    print("Connection failed:", e)
# Out:
# Connection successful!

# %%
engine = engine = create_engine('postgresql+psycopg2://root:root@localhost:5432/Trips_Ingestion')

# %%
df.head(0).to_sql(name="taxi_zone_data", con=engine, if_exists="append")
# Out:
# 0

# %%
print(pd.io.sql.get_schema(df, name='taxi_zone_data', con=engine))
# Out:
# CREATE TABLE taxi_zone_data (
# 	"LocationID" BIGINT,
# 	"Borough" TEXT,
# 	"Zone" TEXT,
# 	service_zone TEXT
# )

# %%
df.to_sql(name='taxi_zone_data',con=engine,if_exists='replace',index=False)
# Out:
# 265
